# %% [markdown]
# <h1><center><b>Anamoly Detection AutoEncoder NN Model</b></center></h1>

# %% [markdown]
# ## Import and Load Dataset

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

import tensorflow as tf
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization, LeakyReLU, Input
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import BinaryCrossentropy
from tensorflow.keras.callbacks import EarlyStopping

from tensorflow.keras.regularizers import l2
from tensorflow.keras.callbacks import LearningRateScheduler, ReduceLROnPlateau

# %%
# Load the preprocessed training and test datasets
train_data = pd.read_csv('dataset_preprocessed/Processed_Train.csv')
test_data = pd.read_csv('dataset_preprocessed/Processed_Test.csv')

# %%
# Separate features and target from the training dataset
X_train = train_data.drop(columns=['target'])
Y_train = train_data['target']
X_test = test_data.drop(columns=['target'])
Y_test = test_data['target']

# %%
X_train_class_1 = X_train[Y_train == 1]
Y_train_class_1 = Y_train[Y_train == 1]
X_test_class_1 = X_test[Y_test == 1]
Y_test_class_1 = Y_test[Y_test == 1]

# %%
print(X_train_class_1.shape)
print(Y_train_class_1.shape)
print(X_train.shape)
print(Y_train.shape)
# Out:
# (74033, 25)
# (74033,)
# (785133, 25)
# (785133,)

# %% [markdown]
# ## Build and train the Encoder (Class 1)

# %%
# Define the autoencoder architecture
encoding_dim = 10  # Dimensionality of the encoded space

autoencoder = Sequential()

# Encoder
autoencoder.add(Input(shape=(X_train_class_1.shape[1],)))

autoencoder.add(Dense(32))
autoencoder.add(LeakyReLU(alpha=0.1))

autoencoder.add(Dense(16))
autoencoder.add(LeakyReLU(alpha=0.1))

autoencoder.add(Dense(encoding_dim))
autoencoder.add(LeakyReLU(alpha=0.1))

# Decoder
autoencoder.add(Dense(16))
autoencoder.add(LeakyReLU(alpha=0.1))

autoencoder.add(Dense(32))
autoencoder.add(LeakyReLU(alpha=0.1))

autoencoder.add(Dense(X_train.shape[1]))

autoencoder.add(LeakyReLU(alpha=0.1))

# Compile the autoencoder
autoencoder.compile(optimizer='adam', loss='mse')
# Out:
# /home/siddhesh/miniconda3/envs/env1/lib/python3.11/site-packages/keras/src/layers/activations/leaky_relu.py:41: UserWarning: Argument `alpha` is deprecated. Use `negative_slope` instead.
#   warnings.warn(

# %%
# Train the autoencoder
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
autoencoder.fit(X_train_class_1, X_train_class_1, 
                epochs=100, 
                batch_size=64, 
                shuffle=True, 
                validation_data=(X_test_class_1, X_test_class_1),
                callbacks=[early_stopping])
# Out:
# Epoch 1/100
# 1157/1157 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.2443 - val_loss: 0.0683
# Epoch 2/100
# 1157/1157 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.0647 - val_loss: 0.0407
# Epoch 3/100
# 1157/1157 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0465 - val_loss: 0.0319
# Epoch 4/100
# 1157/1157 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.0366 - val_loss: 0.0263
# Epoch 5/100
# 1157/1157 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.0315 - val_loss: 0.0236
# Epoch 6/100
# 1157/1157 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.0253 - val_loss: 0.0230
# Epoch 7/100
# 1157/1157 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0245 - val_loss: 0.0189
# Epoch 8/100
# 1157/1157 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.0236 - val_loss: 0.0182
# Epoch 9/100
# 1157/1157 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.0224 - val_loss: 0.0162
# Epoch 10/100
# 1157/1157 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.0206 - val_loss: 0.0152
# Epoch 11/100
# 1157/1157 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0202 - val_loss: 0.0149
# Epoch 12/100
# 1157/1157 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.0198 - val_loss: 0.0147
# Epoch 13/100
# 1157/1157 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0189 - val_loss: 0.0138
# Epoch 14/100
# 1157/1157 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.0201 - val_loss: 0.0130
# Epoch 15/100
# 1157/1157 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0144 - val_loss: 0.0132
# Epoch 16/100
# 1157/1157 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0152 - val_loss: 0.0125
# Epoch 17/100
# 1157/1157 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0153 - val_loss: 0.0122
# Epoch 18/100
# 1157/1157 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0166 - val_loss: 0.0124
# Epoch 19/100
# 1157/1157 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.0131 - val_loss: 0.0115
# Epoch 20/100
# 1157/1157 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0138 - val_loss: 0.0119
# Epoch 21/100
# 1157/1157 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0156 - val_loss: 0.0110
# Epoch 22/100
# 1157/1157 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0156 - val_loss: 0.0128
# Epoch 23/100
# 1157/1157 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0165 - val_loss: 0.0104
# Epoch 24/100
# 1157/1157 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0133 - val_loss: 0.0100
# Epoch 25/100
# 1157/1157 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.0112 - val_loss: 0.0099
# Epoch 26/100
# 1157/1157 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0097 - val_loss: 0.0093
# Epoch 27/100
# 1157/1157 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.0101 - val_loss: 0.0098
# Epoch 28/100
# 1157/1157 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0103 - val_loss: 0.0108
# Epoch 29/100
# 1157/1157 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.0122 - val_loss: 0.0090
# Epoch 30/100
# 1157/1157 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0098 - val_loss: 0.0090
# Epoch 31/100
# 1157/1157 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.0099 - val_loss: 0.0090
# Epoch 32/100
# 1157/1157 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.0091 - val_loss: 0.0089
# Epoch 33/100
# 1157/1157 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.0090 - val_loss: 0.0091
# Epoch 34/100
# 1157/1157 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.0087 - val_loss: 0.0092
# Epoch 35/100
# 1157/1157 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.0112 - val_loss: 0.0086
# Epoch 36/100
# 1157/1157 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0089 - val_loss: 0.0091
# Epoch 37/100
# 1157/1157 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0090 - val_loss: 0.0088
# Epoch 38/100
# 1157/1157 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0087 - val_loss: 0.0087
# Epoch 39/100
# 1157/1157 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.0089 - val_loss: 0.0081
# Epoch 40/100
# 1157/1157 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.0088 - val_loss: 0.0084
# Epoch 41/100
# 1157/1157 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0091 - val_loss: 0.0089
# Epoch 42/100
# 1157/1157 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0086 - val_loss: 0.0079
# Epoch 43/100
# 1157/1157 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0078 - val_loss: 0.0078
# Epoch 44/100
# 1157/1157 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.0089 - val_loss: 0.0079
# Epoch 45/100
# 1157/1157 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.0078 - val_loss: 0.0083
# Epoch 46/100
# 1157/1157 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0088 - val_loss: 0.0073
# Epoch 47/100
# 1157/1157 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0075 - val_loss: 0.0085
# Epoch 48/100
# 1157/1157 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.0086 - val_loss: 0.0078
# Epoch 49/100
# 1157/1157 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.0076 - val_loss: 0.0076
# Epoch 50/100
# 1157/1157 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.0078 - val_loss: 0.0084
# Epoch 51/100
# 1157/1157 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0079 - val_loss: 0.0071
# Epoch 52/100
# 1157/1157 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.0072 - val_loss: 0.0074
# Epoch 53/100
# 1157/1157 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0079 - val_loss: 0.0076
# Epoch 54/100
# 1157/1157 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.0075 - val_loss: 0.0074
# Epoch 55/100
# 1157/1157 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.0077 - val_loss: 0.0078
# Epoch 56/100
# 1157/1157 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.0075 - val_loss: 0.0070
# Epoch 57/100
# 1157/1157 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0074 - val_loss: 0.0071
# Epoch 58/100
# 1157/1157 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0070 - val_loss: 0.0079
# Epoch 59/100
# 1157/1157 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.0079 - val_loss: 0.0067
# Epoch 60/100
# 1157/1157 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0072 - val_loss: 0.0070
# Epoch 61/100
# 1157/1157 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0072 - val_loss: 0.0070
# Epoch 62/100
# 1157/1157 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0071 - val_loss: 0.0069
# Epoch 63/100
# 1157/1157 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0074 - val_loss: 0.0069
# Epoch 64/100
# 1157/1157 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0072 - val_loss: 0.0067
# Epoch 65/100
# 1157/1157 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0071 - val_loss: 0.0069
# Epoch 66/100
# 1157/1157 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.0075 - val_loss: 0.0070
# Epoch 67/100
# 1157/1157 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0068 - val_loss: 0.0075
# Epoch 68/100
# 1157/1157 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.0072 - val_loss: 0.0068
# Epoch 69/100
# 1157/1157 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0067 - val_loss: 0.0067
# Epoch 70/100
# 1157/1157 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0066 - val_loss: 0.0065
# Epoch 71/100
# 1157/1157 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0070 - val_loss: 0.0066
# Epoch 72/100
# 1157/1157 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.0067 - val_loss: 0.0066
# Epoch 73/100
# 1157/1157 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.0071 - val_loss: 0.0071
# Epoch 74/100
# 1157/1157 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0071 - val_loss: 0.0067
# Epoch 75/100
# 1157/1157 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.0067 - val_loss: 0.0061
# Epoch 76/100
# 1157/1157 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0065 - val_loss: 0.0069
# Epoch 77/100
# 1157/1157 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.0067 - val_loss: 0.0082
# Epoch 78/100
# 1157/1157 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0072 - val_loss: 0.0062
# Epoch 79/100
# 1157/1157 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0065 - val_loss: 0.0067
# Epoch 80/100
# 1157/1157 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.0062 - val_loss: 0.0064

# %%
X_train_pred = autoencoder.predict(X_train)
# Out:
# 24536/24536 ━━━━━━━━━━━━━━━━━━━━ 21s 849us/step

# %%
reconstruction_errors_train = np.mean(np.square(X_train - X_train_pred), axis=1)

# %%
# Do the same for X_test
X_test_pred = autoencoder.predict(X_test)
reconstruction_errors_test = np.mean(np.square(X_test - X_test_pred), axis=1)
# Out:
# 8179/8179 ━━━━━━━━━━━━━━━━━━━━ 7s 793us/step

# %%
reconstruction_errors_train = np.array(reconstruction_errors_train)
reconstruction_errors_test = np.array(reconstruction_errors_test)

# %%
import xgboost as xgb

# Train a model using reconstruction errors
clf = xgb.XGBClassifier()

# Fit the classifier using the reconstruction errors and Y_train
clf.fit(reconstruction_errors_train.reshape(-1, 1), Y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...)

# %%
Y_pred = clf.predict(reconstruction_errors_test.reshape(-1, 1))

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# Evaluate the model
accuracy = accuracy_score(Y_test, Y_pred)
print(f"Accuracy: {accuracy * 100:.2f}%")

# Confusion matrix
cm = confusion_matrix(Y_test, Y_pred)
print("\nConfusion Matrix:")
print(cm)

# Classification report
print("\nClassification Report:")
print(classification_report(Y_test, Y_pred))

# Visualizing the confusion matrix
plt.figure(figsize=(6,4))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.title("Confusion Matrix")
plt.ylabel('Actual')
plt.xlabel('Predicted')
plt.show()

from sklearn.metrics import precision_score, recall_score, f1_score, roc_auc_score

# Precision, Recall, F1-Score
precision = precision_score(Y_test, Y_pred)
recall = recall_score(Y_test, Y_pred)
f1 = f1_score(Y_test, Y_pred)
roc_auc = roc_auc_score(Y_test, Y_pred)

print(f"Precision: {precision:.2f}")
print(f"Recall: {recall:.2f}")
print(f"F1-Score: {f1:.2f}")
print(f"ROC-AUC: {roc_auc:.2f}")
# Out:
# Accuracy: 96.35%
#
# Confusion Matrix:
# [[227672   9362]
#  [   191  24487]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      0.96      0.98    237034
#            1       0.72      0.99      0.84     24678
#
#     accuracy                           0.96    261712
#    macro avg       0.86      0.98      0.91    261712
# weighted avg       0.97      0.96      0.97    261712
# Precision: 0.72
# Recall: 0.99
# F1-Score: 0.84
# ROC-AUC: 0.98

# %%
# Define the model
model_meta = Sequential()

model_meta.add(Input(shape=(1,)))

model_meta.add(Dense(4))
model_meta.add(LeakyReLU(alpha=0.1))

model_meta.add(Dense(2))
model_meta.add(LeakyReLU(alpha=0.1))

model_meta.add(Dense(1, activation='sigmoid'))

# Compile the model
model_meta.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy', 'Precision', 'Recall', 'AUC'])

# Summary of the model
model_meta.summary()
# Out:
# /home/siddhesh/miniconda3/envs/env1/lib/python3.11/site-packages/keras/src/layers/activations/leaky_relu.py:41: UserWarning: Argument `alpha` is deprecated. Use `negative_slope` instead.
#   warnings.warn(
# Model: "sequential_12"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_62 (Dense)                │ (None, 4)              │             8 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_54 (LeakyReLU)      │ (None, 4)              │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_63 (Dense)                │ (None, 2)              │            10 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_55 (LeakyReLU)      │ (None, 2)              │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_64 (Dense)                │ (None, 1)              │             3 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 21 (84.00 B)
#  Trainable params: 21 (84.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
tensorboard_callback_meta = tf.keras.callbacks.TensorBoard(log_dir='tf_logs/model_meta_nn', histogram_freq=1)
lr_scheduler_meta = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3, min_lr=1e-6)

model_meta.fit(reconstruction_errors_train, Y_train, 
          epochs=15, 
          batch_size=128, 
          validation_data=(reconstruction_errors_test, Y_test), 
          callbacks=[tensorboard_callback_meta, lr_scheduler_meta]
         )
# Out:
# Epoch 1/15
# 6134/6134 ━━━━━━━━━━━━━━━━━━━━ 25s 4ms/step - AUC: 0.8411 - Precision: 0.4851 - Recall: 0.2779 - accuracy: 0.9226 - loss: 0.2613 - val_AUC: 0.9842 - val_Precision: 0.7297 - val_Recall: 0.9364 - val_accuracy: 0.9613 - val_loss: 0.0827 - learning_rate: 0.0010
# Epoch 2/15
# 6134/6134 ━━━━━━━━━━━━━━━━━━━━ 16s 3ms/step - AUC: 0.9829 - Precision: 0.7299 - Recall: 0.9430 - accuracy: 0.9618 - loss: 0.0828 - val_AUC: 0.9843 - val_Precision: 0.7293 - val_Recall: 0.9414 - val_accuracy: 0.9615 - val_loss: 0.0824 - learning_rate: 0.0010
# Epoch 3/15
# 6134/6134 ━━━━━━━━━━━━━━━━━━━━ 17s 3ms/step - AUC: 0.9832 - Precision: 0.7318 - Recall: 0.9447 - accuracy: 0.9626 - loss: 0.0812 - val_AUC: 0.9843 - val_Precision: 0.7279 - val_Recall: 0.9506 - val_accuracy: 0.9618 - val_loss: 0.0827 - learning_rate: 0.0010
# Epoch 4/15
# 6134/6134 ━━━━━━━━━━━━━━━━━━━━ 17s 3ms/step - AUC: 0.9831 - Precision: 0.7324 - Recall: 0.9440 - accuracy: 0.9622 - loss: 0.0815 - val_AUC: 0.9843 - val_Precision: 0.7325 - val_Recall: 0.9260 - val_accuracy: 0.9611 - val_loss: 0.0830 - learning_rate: 0.0010
# Epoch 5/15
# 6134/6134 ━━━━━━━━━━━━━━━━━━━━ 17s 3ms/step - AUC: 0.9829 - Precision: 0.7325 - Recall: 0.9424 - accuracy: 0.9620 - loss: 0.0821 - val_AUC: 0.9843 - val_Precision: 0.7288 - val_Recall: 0.9447 - val_accuracy: 0.9616 - val_loss: 0.0824 - learning_rate: 0.0010
# Epoch 6/15
# 6134/6134 ━━━━━━━━━━━━━━━━━━━━ 16s 3ms/step - AUC: 0.9836 - Precision: 0.7330 - Recall: 0.9442 - accuracy: 0.9623 - loss: 0.0816 - val_AUC: 0.9844 - val_Precision: 0.7294 - val_Recall: 0.9412 - val_accuracy: 0.9615 - val_loss: 0.0823 - learning_rate: 5.0000e-04
# Epoch 7/15
# 6134/6134 ━━━━━━━━━━━━━━━━━━━━ 16s 3ms/step - AUC: 0.9834 - Precision: 0.7293 - Recall: 0.9424 - accuracy: 0.9613 - loss: 0.0827 - val_AUC: 0.9844 - val_Precision: 0.7286 - val_Recall: 0.9458 - val_accuracy: 0.9617 - val_loss: 0.0824 - learning_rate: 5.0000e-04
# Epoch 8/15
# 6134/6134 ━━━━━━━━━━━━━━━━━━━━ 17s 3ms/step - AUC: 0.9832 - Precision: 0.7284 - Recall: 0.9423 - accuracy: 0.9617 - loss: 0.0821 - val_AUC: 0.9844 - val_Precision: 0.7285 - val_Recall: 0.9479 - val_accuracy: 0.9618 - val_loss: 0.0825 - learning_rate: 5.0000e-04
# Epoch 9/15
# 6134/6134 ━━━━━━━━━━━━━━━━━━━━ 18s 3ms/step - AUC: 0.9837 - Precision: 0.7327 - Recall: 0.9444 - accuracy: 0.9623 - loss: 0.0814 - val_AUC: 0.9843 - val_Precision: 0.7291 - val_Recall: 0.9434 - val_accuracy: 0.9616 - val_loss: 0.0823 - learning_rate: 2.5000e-04
# Epoch 10/15
# 6134/6134 ━━━━━━━━━━━━━━━━━━━━ 15s 2ms/step - AUC: 0.9838 - Precision: 0.7321 - Recall: 0.9436 - accuracy: 0.9622 - loss: 0.0812 - val_AUC: 0.9842 - val_Precision: 0.7292 - val_Recall: 0.9421 - val_accuracy: 0.9615 - val_loss: 0.0823 - learning_rate: 2.5000e-04
# Epoch 11/15
# 6134/6134 ━━━━━━━━━━━━━━━━━━━━ 15s 2ms/step - AUC: 0.9836 - Precision: 0.7312 - Recall: 0.9425 - accuracy: 0.9619 - loss: 0.0818 - val_AUC: 0.9843 - val_Precision: 0.7291 - val_Recall: 0.9436 - val_accuracy: 0.9616 - val_loss: 0.0823 - learning_rate: 2.5000e-04
# Epoch 12/15
# 6134/6134 ━━━━━━━━━━━━━━━━━━━━ 16s 3ms/step - AUC: 0.9839 - Precision: 0.7323 - Recall: 0.9432 - accuracy: 0.9621 - loss: 0.0817 - val_AUC: 0.9844 - val_Precision: 0.7286 - val_Recall: 0.9465 - val_accuracy: 0.9617 - val_loss: 0.0824 - learning_rate: 2.5000e-04
# Epoch 13/15
# 6134/6134 ━━━━━━━━━━━━━━━━━━━━ 15s 2ms/step - AUC: 0.9835 - Precision: 0.7299 - Recall: 0.9441 - accuracy: 0.9618 - loss: 0.0824 - val_AUC: 0.9844 - val_Precision: 0.7288 - val_Recall: 0.9442 - val_accuracy: 0.9616 - val_loss: 0.0823 - learning_rate: 1.2500e-04
# Epoch 14/15
# 6134/6134 ━━━━━━━━━━━━━━━━━━━━ 18s 3ms/step - AUC: 0.9837 - Precision: 0.7291 - Recall: 0.9427 - accuracy: 0.9617 - loss: 0.0818 - val_AUC: 0.9844 - val_Precision: 0.7293 - val_Recall: 0.9413 - val_accuracy: 0.9615 - val_loss: 0.0823 - learning_rate: 1.2500e-04
# Epoch 15/15
# 6134/6134 ━━━━━━━━━━━━━━━━━━━━ 14s 2ms/step - AUC: 0.9837 - Precision: 0.7314 - Recall: 0.9439 - accuracy: 0.9618 - loss: 0.0823 - val_AUC: 0.9843 - val_Precision: 0.7293 - val_Recall: 0.9417 - val_accuracy: 0.9615 - val_loss: 0.0823 - learning_rate: 1.2500e-04

# %%
Y_pred_prob = model_meta.predict(reconstruction_errors_test)

# %%
Y_pred = (Y_pred_prob > 0.5).astype(int).flatten()

# %%
# Evaluate the model
accuracy = accuracy_score(Y_test, Y_pred)
print(f"Meta Model Accuracy: {accuracy * 100:.2f}%")

# Confusion matrix
cm = confusion_matrix(Y_test, Y_pred)
print("\nConfusion Matrix:")
print(cm)

# Classification report
print("\nClassification Report:")
print(classification_report(Y_test, Y_pred))

# Visualizing the confusion matrix
plt.figure(figsize=(6,4))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.title("Confusion Matrix")
plt.ylabel('Actual')
plt.xlabel('Predicted')
plt.show()

# Precision, Recall, F1-Score
precision = precision_score(Y_test, Y_pred)
recall = recall_score(Y_test, Y_pred)
f1 = f1_score(Y_test, Y_pred)
roc_auc = roc_auc_score(Y_test, Y_pred)

print(f"Precision: {precision:.2f}")
print(f"Recall: {recall:.2f}")
print(f"F1-Score: {f1:.2f}")
print(f"ROC-AUC: {roc_auc:.2f}")

# %% [markdown]
# ## Test the model

# %%
X_train_with_error = np.c_[X_train, reconstruction_errors_train]
X_test_with_error = np.c_[X_test, reconstruction_errors_test]

# %%
xgb_classifier = xgb.XGBClassifier()
xgb_classifier.fit(X_train_with_error, Y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...)

# %%
Y_pred = xgb_classifier.predict(X_test_with_error)

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# Evaluate the model
accuracy = accuracy_score(Y_test, Y_pred)
print(f"Accuracy: {accuracy * 100:.2f}%")

# Confusion matrix
cm = confusion_matrix(Y_test, Y_pred)
print("\nConfusion Matrix:")
print(cm)

# Classification report
print("\nClassification Report:")
print(classification_report(Y_test, Y_pred))

# Visualizing the confusion matrix
plt.figure(figsize=(6,4))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.title("Confusion Matrix")
plt.ylabel('Actual')
plt.xlabel('Predicted')
plt.show()

from sklearn.metrics import precision_score, recall_score, f1_score, roc_auc_score

# Precision, Recall, F1-Score
precision = precision_score(Y_test, Y_pred)
recall = recall_score(Y_test, Y_pred)
f1 = f1_score(Y_test, Y_pred)
roc_auc = roc_auc_score(Y_test, Y_pred)

print(f"Precision: {precision:.2f}")
print(f"Recall: {recall:.2f}")
print(f"F1-Score: {f1:.2f}")
print(f"ROC-AUC: {roc_auc:.2f}")
# Out:
# Accuracy: 97.83%
#
# Confusion Matrix:
# [[232940   4094]
#  [  1590  23088]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.99      0.98      0.99    237034
#            1       0.85      0.94      0.89     24678
#
#     accuracy                           0.98    261712
#    macro avg       0.92      0.96      0.94    261712
# weighted avg       0.98      0.98      0.98    261712
# Precision: 0.85
# Recall: 0.94
# F1-Score: 0.89
# ROC-AUC: 0.96

# %%
model = Sequential()

# Input layer
model.add(Dense(64, input_dim=X_train_with_error.shape[1], activation='relu'))
model.add(Dropout(0.4))  # Regularization

# Hidden layers
model.add(Dense(32, activation='relu'))
model.add(BatchNormalization())  # Optional, to improve training stability
model.add(Dropout(0.4))

model.add(Dense(16, activation='relu'))

# Output layer
model.add(Dense(1, activation='sigmoid'))

# Compile model
model.compile(optimizer=Adam(), loss='binary_crossentropy', metrics=['accuracy', 'Precision', 'Recall'])

# %%
model.fit(X_train_with_error, Y_train, 
          epochs=50, 
          batch_size=128, 
          validation_data=(X_test_with_error, Y_test)
         )
# Out:
# Epoch 1/50
# 6134/6134 ━━━━━━━━━━━━━━━━━━━━ 18s 2ms/step - Precision: 0.6577 - Recall: 0.8301 - accuracy: 0.9335 - loss: 0.1532 - val_Precision: 0.8318 - val_Recall: 0.8887 - val_accuracy: 0.9726 - val_loss: 0.0617
# Epoch 2/50
# 6134/6134 ━━━━━━━━━━━━━━━━━━━━ 9s 1ms/step - Precision: 0.8079 - Recall: 0.9179 - accuracy: 0.9718 - loss: 0.0638 - val_Precision: 0.8104 - val_Recall: 0.9385 - val_accuracy: 0.9735 - val_loss: 0.0597
# Epoch 3/50
# 6134/6134 ━━━━━━━━━━━━━━━━━━━━ 9s 1ms/step - Precision: 0.8144 - Recall: 0.9174 - accuracy: 0.9726 - loss: 0.0616 - val_Precision: 0.8200 - val_Recall: 0.9318 - val_accuracy: 0.9743 - val_loss: 0.0583
# Epoch 4/50
# 6134/6134 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step - Precision: 0.8200 - Recall: 0.9194 - accuracy: 0.9733 - loss: 0.0606 - val_Precision: 0.8389 - val_Recall: 0.9069 - val_accuracy: 0.9748 - val_loss: 0.0582
# Epoch 5/50
# 6134/6134 ━━━━━━━━━━━━━━━━━━━━ 9s 1ms/step - Precision: 0.8210 - Recall: 0.9154 - accuracy: 0.9731 - loss: 0.0603 - val_Precision: 0.8246 - val_Recall: 0.9328 - val_accuracy: 0.9750 - val_loss: 0.0576
# Epoch 6/50
# 6134/6134 ━━━━━━━━━━━━━━━━━━━━ 9s 1ms/step - Precision: 0.8204 - Recall: 0.9200 - accuracy: 0.9735 - loss: 0.0597 - val_Precision: 0.8243 - val_Recall: 0.9348 - val_accuracy: 0.9751 - val_loss: 0.0567
# Epoch 7/50
# 6134/6134 ━━━━━━━━━━━━━━━━━━━━ 9s 1ms/step - Precision: 0.8209 - Recall: 0.9215 - accuracy: 0.9737 - loss: 0.0594 - val_Precision: 0.8186 - val_Recall: 0.9422 - val_accuracy: 0.9749 - val_loss: 0.0573
# Epoch 8/50
# 6134/6134 ━━━━━━━━━━━━━━━━━━━━ 9s 1ms/step - Precision: 0.8242 - Recall: 0.9211 - accuracy: 0.9739 - loss: 0.0590 - val_Precision: 0.8314 - val_Recall: 0.9250 - val_accuracy: 0.9752 - val_loss: 0.0570
# Epoch 9/50
# 6134/6134 ━━━━━━━━━━━━━━━━━━━━ 9s 1ms/step - Precision: 0.8218 - Recall: 0.9175 - accuracy: 0.9735 - loss: 0.0593 - val_Precision: 0.8316 - val_Recall: 0.9290 - val_accuracy: 0.9756 - val_loss: 0.0567
# Epoch 10/50
# 6134/6134 ━━━━━━━━━━━━━━━━━━━━ 9s 1ms/step - Precision: 0.8238 - Recall: 0.9212 - accuracy: 0.9740 - loss: 0.0586 - val_Precision: 0.8243 - val_Recall: 0.9386 - val_accuracy: 0.9754 - val_loss: 0.0566
# Epoch 11/50
# 6134/6134 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step - Precision: 0.8236 - Recall: 0.9179 - accuracy: 0.9737 - loss: 0.0591 - val_Precision: 0.8286 - val_Recall: 0.9305 - val_accuracy: 0.9753 - val_loss: 0.0565
# Epoch 12/50
# 6134/6134 ━━━━━━━━━━━━━━━━━━━━ 9s 1ms/step - Precision: 0.8256 - Recall: 0.9209 - accuracy: 0.9743 - loss: 0.0582 - val_Precision: 0.8238 - val_Recall: 0.9403 - val_accuracy: 0.9754 - val_loss: 0.0566
# Epoch 13/50
# 6134/6134 ━━━━━━━━━━━━━━━━━━━━ 11s 2ms/step - Precision: 0.8228 - Recall: 0.9166 - accuracy: 0.9735 - loss: 0.0590 - val_Precision: 0.8243 - val_Recall: 0.9379 - val_accuracy: 0.9753 - val_loss: 0.0565
# Epoch 14/50
# 6134/6134 ━━━━━━━━━━━━━━━━━━━━ 9s 1ms/step - Precision: 0.8249 - Recall: 0.9219 - accuracy: 0.9742 - loss: 0.0582 - val_Precision: 0.8170 - val_Recall: 0.9477 - val_accuracy: 0.9751 - val_loss: 0.0567
# Epoch 15/50
# 6134/6134 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - Precision: 0.8239 - Recall: 0.9236 - accuracy: 0.9741 - loss: 0.0582 - val_Precision: 0.8269 - val_Recall: 0.9340 - val_accuracy: 0.9753 - val_loss: 0.0564
# Epoch 16/50
# 6134/6134 ━━━━━━━━━━━━━━━━━━━━ 9s 1ms/step - Precision: 0.8242 - Recall: 0.9196 - accuracy: 0.9741 - loss: 0.0582 - val_Precision: 0.8279 - val_Recall: 0.9335 - val_accuracy: 0.9754 - val_loss: 0.0562
# Epoch 17/50
# 6134/6134 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - Precision: 0.8257 - Recall: 0.9191 - accuracy: 0.9742 - loss: 0.0578 - val_Precision: 0.8308 - val_Recall: 0.9282 - val_accuracy: 0.9754 - val_loss: 0.0563
# Epoch 18/50
# 6134/6134 ━━━━━━━━━━━━━━━━━━━━ 9s 1ms/step - Precision: 0.8274 - Recall: 0.9173 - accuracy: 0.9741 - loss: 0.0580 - val_Precision: 0.8483 - val_Recall: 0.9023 - val_accuracy: 0.9756 - val_loss: 0.0563
# Epoch 19/50
# 6134/6134 ━━━━━━━━━━━━━━━━━━━━ 9s 1ms/step - Precision: 0.8290 - Recall: 0.9163 - accuracy: 0.9743 - loss: 0.0579 - val_Precision: 0.8314 - val_Recall: 0.9309 - val_accuracy: 0.9757 - val_loss: 0.0563
# Epoch 20/50
# 6134/6134 ━━━━━━━━━━━━━━━━━━━━ 9s 1ms/step - Precision: 0.8288 - Recall: 0.9175 - accuracy: 0.9742 - loss: 0.0578 - val_Precision: 0.8299 - val_Recall: 0.9332 - val_accuracy: 0.9757 - val_loss: 0.0559
# Epoch 21/50
# 6134/6134 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step - Precision: 0.8281 - Recall: 0.9180 - accuracy: 0.9742 - loss: 0.0578 - val_Precision: 0.8383 - val_Recall: 0.9198 - val_accuracy: 0.9757 - val_loss: 0.0559
# Epoch 22/50
# 6134/6134 ━━━━━━━━━━━━━━━━━━━━ 9s 1ms/step - Precision: 0.8294 - Recall: 0.9214 - accuracy: 0.9747 - loss: 0.0574 - val_Precision: 0.8162 - val_Recall: 0.9498 - val_accuracy: 0.9751 - val_loss: 0.0566
# Epoch 23/50
# 6134/6134 ━━━━━━━━━━━━━━━━━━━━ 9s 1ms/step - Precision: 0.8284 - Recall: 0.9204 - accuracy: 0.9745 - loss: 0.0576 - val_Precision: 0.8210 - val_Recall: 0.9446 - val_accuracy: 0.9754 - val_loss: 0.0562
# Epoch 24/50
# 6134/6134 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step - Precision: 0.8256 - Recall: 0.9198 - accuracy: 0.9740 - loss: 0.0585 - val_Precision: 0.8307 - val_Recall: 0.9326 - val_accuracy: 0.9757 - val_loss: 0.0558
# Epoch 25/50
# 6134/6134 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step - Precision: 0.8280 - Recall: 0.9164 - accuracy: 0.9742 - loss: 0.0578 - val_Precision: 0.8259 - val_Recall: 0.9393 - val_accuracy: 0.9756 - val_loss: 0.0558
# Epoch 26/50
# 3529/6134 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - Precision: 0.8272 - Recall: 0.9165 - accuracy: 0.9743 - loss: 0.0576
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[118], line 1
# ----> 1 model.fit(X_train_with_error, Y_train,
#       2           epochs=50,
#       3           batch_size=128,
#       4           validation_data=(X_test_with_error, Y_test)
#       5          )
#
# File ~/miniconda3/envs/env1/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/miniconda3/envs/env1/lib/python3.11/site-packages/keras/src/backend/tensorflow/trainer.py:320, in TensorFlowTrainer.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq)
#     318 for step, iterator in epoch_iterator.enumerate_epoch():
#     319     callbacks.on_train_batch_begin(step)
# --> 320     logs = self.train_function(iterator)
#     321     logs = self._pythonify_logs(logs)
#     322     callbacks.on_train_batch_end(step, logs)
#
# File ~/miniconda3/envs/env1/lib/python3.11/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/miniconda3/envs/env1/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:833, in Function.__call__(self, *args, **kwds)
#     830 compiler = "xla" if self._jit_compile else "nonXla"
#     832 with OptionalXlaContext(self._jit_compile):
# --> 833   result = self._call(*args, **kwds)
#     835 new_tracing_count = self.experimental_get_tracing_count()
#     836 without_tracing = (tracing_count == new_tracing_count)
#
# File ~/miniconda3/envs/env1/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:878, in Function._call(self, *args, **kwds)
#     875 self._lock.release()
#     876 # In this case we have not created variables on the first call. So we can
#     877 # run the first trace but we should fail if variables are created.
# --> 878 results = tracing_compilation.call_function(
#     879     args, kwds, self._variable_creation_config
#     880 )
#     881 if self._created_variables:
#     882   raise ValueError("Creating variables on a non-first call to a function"
#     883                    " decorated with tf.function.")
#
# File ~/miniconda3/envs/env1/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py:132, in call_function(args, kwargs, tracing_options)
#     130 args = args if args else ()
#     131 kwargs = kwargs if kwargs else {}
# --> 132 function = trace_function(
#     133     args=args, kwargs=kwargs, tracing_options=tracing_options
#     134 )
#     136 # Bind it ourselves to skip unnecessary canonicalization of default call.
#     137 bound_args = function.function_type.bind(*args, **kwargs)
#
# File ~/miniconda3/envs/env1/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py:178, in trace_function(args, kwargs, tracing_options)
#     175     args = tracing_options.input_signature
#     176     kwargs = {}
# --> 178   concrete_function = _maybe_define_function(
#     179       args, kwargs, tracing_options
#     180   )
#     182 if not tracing_options.bind_graph_to_function:
#     183   concrete_function._garbage_collector.release()  # pylint: disable=protected-access
#
# File ~/miniconda3/envs/env1/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py:205, in _maybe_define_function(args, kwargs, tracing_options)
#     188 def _maybe_define_function(args, kwargs, tracing_options):
#     189   """Gets a function for these inputs, defining it if necessary.
#     190
#     191   Args:
#    (...)
#     203       shape relaxation retracing.
#     204   """
# --> 205   bound_args = function_type_utils.canonicalize_function_inputs(
#     206       args,
#     207       kwargs,
#     208       tracing_options.polymorphic_type,
#     209       tracing_options.default_values,
#     210       tracing_options.is_pure,
#     211   )
#     212   args, kwargs = bound_args.args, bound_args.kwargs
#     214   if tracing_options.input_signature is not None:
#
# File ~/miniconda3/envs/env1/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/function_type_utils.py:383, in canonicalize_function_inputs(args, kwargs, function_type, default_values, is_pure)
#     374   function_type, type_context = (
#     375       function_type_lib.canonicalize_to_monomorphic(
#     376           args, kwargs, {}, capture_types, polymorphic_type
#     377       )
#     378   )
#     380   return function_type, type_context
# --> 383 def canonicalize_function_inputs(
#     384     args, kwargs, function_type, default_values=None, is_pure=False
#     385 ):
#     386   """Canonicalizes `args` and `kwargs`.
#     387
#     388   Canonicalize the inputs to the Python function using FunctionType.
#    (...)
#     417       do not conform to the input signature.
#     418   """
#     419   default_values = {} if not default_values else default_values
#
# KeyboardInterrupt:

# %%
Y_pred_prob = model.predict(X_test_with_error)
# Out:
# 8179/8179 ━━━━━━━━━━━━━━━━━━━━ 8s 889us/step

# %%
Y_pred = (Y_pred_prob > 0.485).astype(int).flatten()

# %%
# Evaluate the model
accuracy = accuracy_score(Y_test, Y_pred)
print(f"Accuracy: {accuracy * 100:.2f}%")

# Confusion matrix
cm = confusion_matrix(Y_test, Y_pred)
print("\nConfusion Matrix:")
print(cm)

# Classification report
print("\nClassification Report:")
print(classification_report(Y_test, Y_pred))

# Visualizing the confusion matrix
plt.figure(figsize=(6,4))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.title("Confusion Matrix")
plt.ylabel('Actual')
plt.xlabel('Predicted')
plt.show()
# Out:
# Accuracy: 97.59%
#
# Confusion Matrix:
# [[232585   4449]
#  [  1868  22810]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.99      0.98      0.99    237034
#            1       0.84      0.92      0.88     24678
#
#     accuracy                           0.98    261712
#    macro avg       0.91      0.95      0.93    261712
# weighted avg       0.98      0.98      0.98    261712
