# %% [markdown]
# <h1><center><b>AutoEncoder Pretrained NN Model</b></center></h1>

# %% [markdown]
# ## Import and Load Dataset

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization, LeakyReLU, Input
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import BinaryCrossentropy
from tensorflow.keras.callbacks import EarlyStopping

from tensorflow.keras.regularizers import l2
from tensorflow.keras.callbacks import LearningRateScheduler, ReduceLROnPlateau

# %%
# Load the preprocessed training and test datasets
train_data = pd.read_csv('dataset_preprocessed/LinearImput_Feature_Scale_Cap_Clean_Train.csv')
test_data = pd.read_csv('dataset_preprocessed/LinearImput_Feature_Scale_Cap_Clean_Test.csv')

# %%
# Separate features and target from the training dataset
X_train = train_data.drop(columns=['target'])
Y_train = train_data['target']
X_test = test_data.drop(columns=['target'])
Y_test = test_data['target']

# %% [markdown]
# ## Build and train the Encoder

# %%
# Define the autoencoder architecture
encoding_dim = 10  # Dimensionality of the encoded space

autoencoder = Sequential()

# Encoder
autoencoder.add(Input(shape=(X_train.shape[1],)))

autoencoder.add(Dense(32))
autoencoder.add(LeakyReLU(alpha=0.1))

autoencoder.add(Dense(16))
autoencoder.add(LeakyReLU(alpha=0.1))

autoencoder.add(Dense(encoding_dim))
autoencoder.add(LeakyReLU(alpha=0.1))

# Decoder
autoencoder.add(Dense(16))
autoencoder.add(LeakyReLU(alpha=0.1))

autoencoder.add(Dense(32))
autoencoder.add(LeakyReLU(alpha=0.1))

autoencoder.add(Dense(X_train.shape[1]))

autoencoder.add(LeakyReLU(alpha=0.1))

# Compile the autoencoder
autoencoder.compile(optimizer='adam', loss='mse')
# Out:
# /home/siddhesh/miniconda3/envs/env1/lib/python3.11/site-packages/keras/src/layers/activations/leaky_relu.py:41: UserWarning: Argument `alpha` is deprecated. Use `negative_slope` instead.
#   warnings.warn(

# %%
# Train the autoencoder
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
autoencoder.fit(X_train, X_train, 
                epochs=50, 
                batch_size=256, 
                shuffle=True, 
                validation_data=(X_test, X_test),
                callbacks=[early_stopping])
# Out:
# Epoch 1/50
# 3067/3067 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - loss: 0.1700 - val_loss: 0.0466
# Epoch 2/50
# 3067/3067 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 0.0351 - val_loss: 0.0205
# Epoch 3/50
# 3067/3067 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - loss: 0.0198 - val_loss: 0.0177
# Epoch 4/50
# 3067/3067 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 0.0170 - val_loss: 0.0168
# Epoch 5/50
# 3067/3067 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 0.0156 - val_loss: 0.0145
# Epoch 6/50
# 3067/3067 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 0.0145 - val_loss: 0.0133
# Epoch 7/50
# 3067/3067 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 0.0133 - val_loss: 0.0137
# Epoch 8/50
# 3067/3067 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.0126 - val_loss: 0.0125
# Epoch 9/50
# 3067/3067 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.0119 - val_loss: 0.0113
# Epoch 10/50
# 3067/3067 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - loss: 0.0113 - val_loss: 0.0106
# Epoch 11/50
# 3067/3067 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 0.0108 - val_loss: 0.0097
# Epoch 12/50
# 3067/3067 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 0.0091 - val_loss: 0.0084
# Epoch 13/50
# 3067/3067 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - loss: 0.0079 - val_loss: 0.0102
# Epoch 14/50
# 3067/3067 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 0.0074 - val_loss: 0.0077
# Epoch 15/50
# 3067/3067 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 0.0071 - val_loss: 0.0066
# Epoch 16/50
# 3067/3067 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 0.0068 - val_loss: 0.0072
# Epoch 17/50
# 3067/3067 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 0.0067 - val_loss: 0.0080
# Epoch 18/50
# 3067/3067 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 0.0065 - val_loss: 0.0065
# Epoch 19/50
# 3067/3067 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 0.0064 - val_loss: 0.0074
# Epoch 20/50
# 3067/3067 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - loss: 0.0063 - val_loss: 0.0070
# Epoch 21/50
# 3067/3067 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.0060 - val_loss: 0.0063
# Epoch 22/50
# 3067/3067 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.0059 - val_loss: 0.0059
# Epoch 23/50
# 3067/3067 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.0057 - val_loss: 0.0059
# Epoch 24/50
# 3067/3067 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 0.0057 - val_loss: 0.0055
# Epoch 25/50
# 3067/3067 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.0056 - val_loss: 0.0058
# Epoch 26/50
# 3067/3067 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 0.0054 - val_loss: 0.0053
# Epoch 27/50
# 3067/3067 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - loss: 0.0056 - val_loss: 0.0055
# Epoch 28/50
# 3067/3067 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 0.0053 - val_loss: 0.0051
# Epoch 29/50
# 3067/3067 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 0.0053 - val_loss: 0.0052
# Epoch 30/50
# 3067/3067 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.0054 - val_loss: 0.0048
# Epoch 31/50
# 3067/3067 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 0.0051 - val_loss: 0.0048
# Epoch 32/50
# 3067/3067 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 0.0049 - val_loss: 0.0049
# Epoch 33/50
# 3067/3067 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 0.0049 - val_loss: 0.0055
# Epoch 34/50
# 3067/3067 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 0.0048 - val_loss: 0.0049
# Epoch 35/50
# 3067/3067 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 0.0051 - val_loss: 0.0051
# Epoch 36/50
# 3067/3067 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 0.0048 - val_loss: 0.0045
# Epoch 37/50
# 3067/3067 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 0.0046 - val_loss: 0.0046
# Epoch 38/50
# 3067/3067 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 0.0048 - val_loss: 0.0055
# Epoch 39/50
# 3067/3067 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 0.0048 - val_loss: 0.0044
# Epoch 40/50
# 3067/3067 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.0047 - val_loss: 0.0046
# Epoch 41/50
# 3067/3067 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 0.0046 - val_loss: 0.0055
# Epoch 42/50
# 3067/3067 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 0.0047 - val_loss: 0.0046
# Epoch 43/50
# 3067/3067 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 0.0046 - val_loss: 0.0059
# Epoch 44/50
# 3067/3067 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.0045 - val_loss: 0.0045

# %%
# The input to the autoencoder
encoder_input = Input(shape=(X_train.shape[1],))

# Build the encoder using the layers from the autoencoder
x = autoencoder.layers[0](encoder_input)  # Dense(32)
x = autoencoder.layers[1](x)  # LeakyReLU
x = autoencoder.layers[2](x)  # Dense(16)
x = autoencoder.layers[3](x)  # LeakyReLU
x = autoencoder.layers[4](x)  # Dense(encoding_dim)
encoder_output = autoencoder.layers[5](x)  # LeakyReLU (encoded output)

# Create the encoder model
encoder = Model(inputs=encoder_input, outputs=encoder_output)

# %%
# Extract the encoded representations for the training and testing data
X_train_encoded = encoder.predict(X_train)
X_test_encoded = encoder.predict(X_test)
# Out:
# 24536/24536 ━━━━━━━━━━━━━━━━━━━━ 20s 801us/step
# 8179/8179 ━━━━━━━━━━━━━━━━━━━━ 7s 806us/step

# %%
print(X_train_encoded.shape)
# Out:
# (785133, 10)

# %%
# Save the encoder model
encoder.save('tf_models/encoder_model.keras')

# %% [markdown]
# ## Build and train the classifier on top of encoder

# %%
model = Sequential()

# Input layer
model.add(Input(shape=(encoding_dim,)))

model.add(Dense(256))
model.add(LeakyReLU(alpha=0.1))

model.add(Dense(128))
model.add(LeakyReLU(alpha=0.1))
#model.add(BatchNormalization())
#model.add(Dropout(0.3))  # Regularization

# Hidden layers
model.add(Dense(64))
model.add(LeakyReLU(alpha=0.1))
#model.add(Dropout(0.3))

model.add(Dense(32))
model.add(LeakyReLU(alpha=0.1))

model.add(Dense(8))
model.add(LeakyReLU(alpha=0.1))

# Output layer
model.add(Dense(1, activation='sigmoid'))

# Compile model
optimizer = Adam(learning_rate=0.001)
model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy', 'Precision', 'Recall', 'AUC'])
# Out:
# /home/siddhesh/miniconda3/envs/env1/lib/python3.11/site-packages/keras/src/layers/activations/leaky_relu.py:41: UserWarning: Argument `alpha` is deprecated. Use `negative_slope` instead.
#   warnings.warn(

# %%
lr_scheduler = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3, min_lr=1e-6)
early_stopping_classifier = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

model.fit(X_train_encoded, Y_train,
          epochs=50, 
          batch_size=256, 
          validation_data=(X_test_encoded, Y_test), 
          callbacks=[lr_scheduler, early_stopping_classifier]
         )
# Out:
# Epoch 1/50
# 3067/3067 ━━━━━━━━━━━━━━━━━━━━ 17s 4ms/step - AUC: 0.9692 - Precision: 0.7684 - Recall: 0.7434 - accuracy: 0.9561 - loss: 0.1093 - val_AUC: 0.9920 - val_Precision: 0.7969 - val_Recall: 0.9457 - val_accuracy: 0.9722 - val_loss: 0.0620 - learning_rate: 0.0010
# Epoch 2/50
# 3067/3067 ━━━━━━━━━━━━━━━━━━━━ 7s 2ms/step - AUC: 0.9882 - Precision: 0.8077 - Recall: 0.8677 - accuracy: 0.9681 - loss: 0.0748 - val_AUC: 0.9920 - val_Precision: 0.8444 - val_Recall: 0.8799 - val_accuracy: 0.9734 - val_loss: 0.0614 - learning_rate: 0.0010
# Epoch 3/50
# 3067/3067 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - AUC: 0.9912 - Precision: 0.8222 - Recall: 0.8986 - accuracy: 0.9720 - loss: 0.0636 - val_AUC: 0.9922 - val_Precision: 0.8427 - val_Recall: 0.8852 - val_accuracy: 0.9736 - val_loss: 0.0603 - learning_rate: 0.0010
# Epoch 4/50
# 3067/3067 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - AUC: 0.9901 - Precision: 0.8165 - Recall: 0.8769 - accuracy: 0.9699 - loss: 0.0682 - val_AUC: 0.9911 - val_Precision: 0.8305 - val_Recall: 0.9072 - val_accuracy: 0.9738 - val_loss: 0.0623 - learning_rate: 0.0010
# Epoch 5/50
# 3067/3067 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - AUC: 0.9916 - Precision: 0.8218 - Recall: 0.9049 - accuracy: 0.9725 - loss: 0.0625 - val_AUC: 0.9924 - val_Precision: 0.8247 - val_Recall: 0.9220 - val_accuracy: 0.9742 - val_loss: 0.0590 - learning_rate: 0.0010
# Epoch 6/50
# 3067/3067 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - AUC: 0.9918 - Precision: 0.8260 - Recall: 0.9076 - accuracy: 0.9732 - loss: 0.0613 - val_AUC: 0.9923 - val_Precision: 0.8142 - val_Recall: 0.9337 - val_accuracy: 0.9737 - val_loss: 0.0602 - learning_rate: 0.0010
# Epoch 7/50
# 3067/3067 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - AUC: 0.9919 - Precision: 0.8281 - Recall: 0.9053 - accuracy: 0.9733 - loss: 0.0610 - val_AUC: 0.9924 - val_Precision: 0.8424 - val_Recall: 0.8936 - val_accuracy: 0.9742 - val_loss: 0.0600 - learning_rate: 0.0010
# Epoch 8/50
# 3067/3067 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - AUC: 0.9920 - Precision: 0.8297 - Recall: 0.9028 - accuracy: 0.9734 - loss: 0.0607 - val_AUC: 0.9926 - val_Precision: 0.8204 - val_Recall: 0.9303 - val_accuracy: 0.9742 - val_loss: 0.0585 - learning_rate: 0.0010
# Epoch 9/50
# 3067/3067 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - AUC: 0.9916 - Precision: 0.8265 - Recall: 0.9035 - accuracy: 0.9729 - loss: 0.0622 - val_AUC: 0.9921 - val_Precision: 0.8071 - val_Recall: 0.9341 - val_accuracy: 0.9727 - val_loss: 0.0616 - learning_rate: 0.0010
# Epoch 10/50
# 3067/3067 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - AUC: 0.9913 - Precision: 0.8169 - Recall: 0.9098 - accuracy: 0.9722 - loss: 0.0627 - val_AUC: 0.9924 - val_Precision: 0.8190 - val_Recall: 0.9261 - val_accuracy: 0.9737 - val_loss: 0.0608 - learning_rate: 0.0010
# Epoch 11/50
# 3067/3067 ━━━━━━━━━━━━━━━━━━━━ 7s 2ms/step - AUC: 0.9920 - Precision: 0.8217 - Recall: 0.9094 - accuracy: 0.9730 - loss: 0.0606 - val_AUC: 0.9924 - val_Precision: 0.8269 - val_Recall: 0.9166 - val_accuracy: 0.9740 - val_loss: 0.0591 - learning_rate: 0.0010
# Epoch 12/50
# 3067/3067 ━━━━━━━━━━━━━━━━━━━━ 7s 2ms/step - AUC: 0.9923 - Precision: 0.8282 - Recall: 0.9115 - accuracy: 0.9738 - loss: 0.0593 - val_AUC: 0.9925 - val_Precision: 0.8294 - val_Recall: 0.9124 - val_accuracy: 0.9740 - val_loss: 0.0587 - learning_rate: 5.0000e-04
# Epoch 13/50
# 3067/3067 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - AUC: 0.9924 - Precision: 0.8302 - Recall: 0.9104 - accuracy: 0.9740 - loss: 0.0591 - val_AUC: 0.9926 - val_Precision: 0.8403 - val_Recall: 0.9000 - val_accuracy: 0.9744 - val_loss: 0.0584 - learning_rate: 5.0000e-04
# Epoch 14/50
# 3067/3067 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - AUC: 0.9924 - Precision: 0.8302 - Recall: 0.9117 - accuracy: 0.9740 - loss: 0.0592 - val_AUC: 0.9926 - val_Precision: 0.8406 - val_Recall: 0.8973 - val_accuracy: 0.9743 - val_loss: 0.0586 - learning_rate: 5.0000e-04
# Epoch 15/50
# 3067/3067 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - AUC: 0.9923 - Precision: 0.8290 - Recall: 0.9120 - accuracy: 0.9740 - loss: 0.0591 - val_AUC: 0.9924 - val_Precision: 0.8098 - val_Recall: 0.9364 - val_accuracy: 0.9733 - val_loss: 0.0603 - learning_rate: 5.0000e-04
# Epoch 16/50
# 3067/3067 ━━━━━━━━━━━━━━━━━━━━ 7s 2ms/step - AUC: 0.9924 - Precision: 0.8295 - Recall: 0.9116 - accuracy: 0.9740 - loss: 0.0588 - val_AUC: 0.9926 - val_Precision: 0.8157 - val_Recall: 0.9376 - val_accuracy: 0.9741 - val_loss: 0.0584 - learning_rate: 5.0000e-04
# Epoch 17/50
# 3067/3067 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - AUC: 0.9926 - Precision: 0.8343 - Recall: 0.9156 - accuracy: 0.9749 - loss: 0.0576 - val_AUC: 0.9927 - val_Precision: 0.8331 - val_Recall: 0.9209 - val_accuracy: 0.9752 - val_loss: 0.0572 - learning_rate: 2.5000e-04
# Epoch 18/50
# 3067/3067 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - AUC: 0.9926 - Precision: 0.8341 - Recall: 0.9138 - accuracy: 0.9748 - loss: 0.0574 - val_AUC: 0.9926 - val_Precision: 0.8409 - val_Recall: 0.9048 - val_accuracy: 0.9749 - val_loss: 0.0575 - learning_rate: 2.5000e-04
# Epoch 19/50
# 3067/3067 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - AUC: 0.9927 - Precision: 0.8348 - Recall: 0.9130 - accuracy: 0.9747 - loss: 0.0574 - val_AUC: 0.9928 - val_Precision: 0.8314 - val_Recall: 0.9232 - val_accuracy: 0.9751 - val_loss: 0.0570 - learning_rate: 2.5000e-04
# Epoch 20/50
# 3067/3067 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - AUC: 0.9926 - Precision: 0.8329 - Recall: 0.9211 - accuracy: 0.9749 - loss: 0.0576 - val_AUC: 0.9927 - val_Precision: 0.8438 - val_Recall: 0.9044 - val_accuracy: 0.9752 - val_loss: 0.0570 - learning_rate: 2.5000e-04
# Epoch 21/50
# 3067/3067 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - AUC: 0.9927 - Precision: 0.8348 - Recall: 0.9132 - accuracy: 0.9748 - loss: 0.0572 - val_AUC: 0.9928 - val_Precision: 0.8239 - val_Recall: 0.9323 - val_accuracy: 0.9748 - val_loss: 0.0576 - learning_rate: 2.5000e-04
# Epoch 22/50
# 3067/3067 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - AUC: 0.9926 - Precision: 0.8334 - Recall: 0.9172 - accuracy: 0.9748 - loss: 0.0574 - val_AUC: 0.9918 - val_Precision: 0.8418 - val_Recall: 0.9079 - val_accuracy: 0.9752 - val_loss: 0.0593 - learning_rate: 2.5000e-04
# Epoch 23/50
# 3067/3067 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - AUC: 0.9929 - Precision: 0.8347 - Recall: 0.9161 - accuracy: 0.9751 - loss: 0.0564 - val_AUC: 0.9930 - val_Precision: 0.8282 - val_Recall: 0.9311 - val_accuracy: 0.9753 - val_loss: 0.0566 - learning_rate: 1.2500e-04
# Epoch 24/50
# 3067/3067 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - AUC: 0.9929 - Precision: 0.8353 - Recall: 0.9182 - accuracy: 0.9752 - loss: 0.0564 - val_AUC: 0.9928 - val_Precision: 0.8399 - val_Recall: 0.9156 - val_accuracy: 0.9756 - val_loss: 0.0565 - learning_rate: 1.2500e-04
# Epoch 25/50
# 3067/3067 ━━━━━━━━━━━━━━━━━━━━ 7s 2ms/step - AUC: 0.9929 - Precision: 0.8378 - Recall: 0.9168 - accuracy: 0.9753 - loss: 0.0565 - val_AUC: 0.9928 - val_Precision: 0.8289 - val_Recall: 0.9294 - val_accuracy: 0.9753 - val_loss: 0.0567 - learning_rate: 1.2500e-04
# Epoch 26/50
# 3067/3067 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - AUC: 0.9930 - Precision: 0.8384 - Recall: 0.9183 - accuracy: 0.9756 - loss: 0.0560 - val_AUC: 0.9930 - val_Precision: 0.8298 - val_Recall: 0.9299 - val_accuracy: 0.9754 - val_loss: 0.0565 - learning_rate: 1.2500e-04
# Epoch 27/50
# 3067/3067 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - AUC: 0.9929 - Precision: 0.8339 - Recall: 0.9188 - accuracy: 0.9752 - loss: 0.0564 - val_AUC: 0.9928 - val_Precision: 0.8130 - val_Recall: 0.9421 - val_accuracy: 0.9741 - val_loss: 0.0585 - learning_rate: 1.2500e-04
# Epoch 28/50
# 3067/3067 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - AUC: 0.9929 - Precision: 0.8355 - Recall: 0.9197 - accuracy: 0.9753 - loss: 0.0564 - val_AUC: 0.9930 - val_Precision: 0.8378 - val_Recall: 0.9175 - val_accuracy: 0.9755 - val_loss: 0.0562 - learning_rate: 6.2500e-05
# Epoch 29/50
# 3067/3067 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - AUC: 0.9931 - Precision: 0.8386 - Recall: 0.9182 - accuracy: 0.9755 - loss: 0.0559 - val_AUC: 0.9929 - val_Precision: 0.8347 - val_Recall: 0.9226 - val_accuracy: 0.9755 - val_loss: 0.0563 - learning_rate: 6.2500e-05
# Epoch 30/50
# 3067/3067 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - AUC: 0.9930 - Precision: 0.8360 - Recall: 0.9209 - accuracy: 0.9754 - loss: 0.0562 - val_AUC: 0.9929 - val_Precision: 0.8398 - val_Recall: 0.9155 - val_accuracy: 0.9756 - val_loss: 0.0562 - learning_rate: 6.2500e-05
# Epoch 31/50
# 3067/3067 ━━━━━━━━━━━━━━━━━━━━ 7s 2ms/step - AUC: 0.9930 - Precision: 0.8365 - Recall: 0.9215 - accuracy: 0.9756 - loss: 0.0559 - val_AUC: 0.9930 - val_Precision: 0.8404 - val_Recall: 0.9137 - val_accuracy: 0.9755 - val_loss: 0.0562 - learning_rate: 6.2500e-05
# Epoch 32/50
# 3067/3067 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - AUC: 0.9931 - Precision: 0.8366 - Recall: 0.9188 - accuracy: 0.9755 - loss: 0.0556 - val_AUC: 0.9929 - val_Precision: 0.8373 - val_Recall: 0.9202 - val_accuracy: 0.9756 - val_loss: 0.0561 - learning_rate: 3.1250e-05
# Epoch 33/50
# 3067/3067 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - AUC: 0.9931 - Precision: 0.8380 - Recall: 0.9205 - accuracy: 0.9757 - loss: 0.0556 - val_AUC: 0.9930 - val_Precision: 0.8391 - val_Recall: 0.9173 - val_accuracy: 0.9756 - val_loss: 0.0561 - learning_rate: 3.1250e-05
# Epoch 34/50
# 3067/3067 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - AUC: 0.9931 - Precision: 0.8385 - Recall: 0.9190 - accuracy: 0.9756 - loss: 0.0555 - val_AUC: 0.9930 - val_Precision: 0.8354 - val_Recall: 0.9219 - val_accuracy: 0.9755 - val_loss: 0.0561 - learning_rate: 3.1250e-05
# Epoch 35/50
# 3067/3067 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - AUC: 0.9929 - Precision: 0.8349 - Recall: 0.9215 - accuracy: 0.9754 - loss: 0.0563 - val_AUC: 0.9930 - val_Precision: 0.8337 - val_Recall: 0.9242 - val_accuracy: 0.9755 - val_loss: 0.0561 - learning_rate: 3.1250e-05
# Epoch 36/50
# 3067/3067 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - AUC: 0.9929 - Precision: 0.8359 - Recall: 0.9208 - accuracy: 0.9754 - loss: 0.0562 - val_AUC: 0.9930 - val_Precision: 0.8357 - val_Recall: 0.9228 - val_accuracy: 0.9756 - val_loss: 0.0561 - learning_rate: 3.1250e-05
# Epoch 37/50
# 3067/3067 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - AUC: 0.9931 - Precision: 0.8370 - Recall: 0.9200 - accuracy: 0.9755 - loss: 0.0556 - val_AUC: 0.9929 - val_Precision: 0.8374 - val_Recall: 0.9207 - val_accuracy: 0.9757 - val_loss: 0.0562 - learning_rate: 1.5625e-05
# Epoch 38/50
# 3067/3067 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - AUC: 0.9931 - Precision: 0.8377 - Recall: 0.9205 - accuracy: 0.9756 - loss: 0.0557 - val_AUC: 0.9930 - val_Precision: 0.8377 - val_Recall: 0.9194 - val_accuracy: 0.9756 - val_loss: 0.0561 - learning_rate: 1.5625e-05

# %% [markdown]
# ## Test the model

# %%
# Make predictions on the test set
Y_pred_prob = model.predict(X_test_encoded)
# Out:
# 8179/8179 ━━━━━━━━━━━━━━━━━━━━ 8s 937us/step

# %%
Y_pred = (Y_pred_prob > 0.5).astype(int).flatten()

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# Evaluate the model
accuracy = accuracy_score(Y_test, Y_pred)
print(f"Accuracy: {accuracy * 100:.2f}%")

# Confusion matrix
cm = confusion_matrix(Y_test, Y_pred)
print("\nConfusion Matrix:")
print(cm)

# Classification report
print("\nClassification Report:")
print(classification_report(Y_test, Y_pred))

# Visualizing the confusion matrix
plt.figure(figsize=(6,4))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.title("Confusion Matrix")
plt.ylabel('Actual')
plt.xlabel('Predicted')
plt.show()

from sklearn.metrics import precision_score, recall_score, f1_score, roc_auc_score

# Precision, Recall, F1-Score
precision = precision_score(Y_test, Y_pred)
recall = recall_score(Y_test, Y_pred)
f1 = f1_score(Y_test, Y_pred)
roc_auc = roc_auc_score(Y_test, Y_pred)

print(f"Precision: {precision:.2f}")
print(f"Recall: {recall:.2f}")
print(f"F1-Score: {f1:.2f}")
print(f"ROC-AUC: {roc_auc:.2f}")
# Out:
# Accuracy: 97.56%
#
# Confusion Matrix:
# [[232694   4340]
#  [  2040  22638]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.99      0.98      0.99    237034
#            1       0.84      0.92      0.88     24678
#
#     accuracy                           0.98    261712
#    macro avg       0.92      0.95      0.93    261712
# weighted avg       0.98      0.98      0.98    261712
# Precision: 0.84
# Recall: 0.92
# F1-Score: 0.88
# ROC-AUC: 0.95
